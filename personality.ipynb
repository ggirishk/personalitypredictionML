# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# output.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('output.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'output.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 315 rows and 2 columns

# %%
df1.head(5)
# Out:
#    Person No Predicted Personality
# 0          1            dependable
# 1          2               serious
# 2          3               serious
# 3          4               serious
# 4          5           responsible

# %%
df1.tail(5)
# Out:
#      Person No Predicted Personality
# 310        311           extraverted
# 311        312               serious
# 312        313               serious
# 313        314           extraverted
# 314        315           extraverted

# %%
df1.describe()
# Out:
#         Person No
# count  315.000000
# mean   158.000000
# std     91.076891
# min      1.000000
# 25%     79.500000
# 50%    158.000000
# 75%    236.500000
# max    315.000000

# %%
df1.shape
# Out:
# (315, 2)

# %%
df1.isnull().sum()
# Out:
# Person No                0
# Predicted Personality    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# test.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df2 = pd.read_csv('test.csv', delimiter=',', nrows = nRowsRead)
df2.dataframeName = 'test.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 531 rows and 8 columns

# %%
df2.head(10)
# Out:
#    Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0  Female   20         7            9                  9              5
# 1    Male   17         5            4                  5              2
# 2  Female   25         5            5                  7              2
# 3  Female   18         6            2                  7              4
# 4  Female   19         2            4                  7              1
# 5  Female   19         6            4                  7              5
# 6  Female   24         1            2                  7              4
# 7    Male   27         4            5                  7              4
# 8    Male   20         6            4                  5              6
# 9    Male   21         5            4                  4              6
#
#    extraversion Personality (class label)
# 0             5                dependable
# 1             4                   serious
# 2             4                   serious
# 3             7                   serious
# 4             3               responsible
# 5             5                   serious
# 6             6               extraverted
# 7             4                   serious
# 8             6                   serious
# 9             4                   serious

# %%
df2.tail()
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 526  Female   20         5            6                  2              2
# 527    Male   18         6            5                  5              5
# 528    Male   19         1            5                  4              7
# 529  Female   22         3            3                  2              6
# 530  Female   17         6            6                  3              6
#
#      extraversion Personality (class label)
# 526             3               extraverted
# 527             7                   serious
# 528             6                   serious
# 529             4               responsible
# 530             5               extraverted

# %%
df2.shape
# Out:
# (531, 8)

# %%
df2.describe()
# Out:
#               Age    openness  neuroticism  conscientiousness  agreeableness  \
# count  531.000000  531.000000   531.000000         531.000000      531.00000
# mean    20.122411    4.860640     4.917137           4.838041        4.94162
# std      2.493404    1.587503     1.709217           1.805689        1.62944
# min      5.000000    1.000000     1.000000           1.000000        1.00000
# 25%     18.000000    4.000000     4.000000           3.000000        4.00000
# 50%     19.000000    5.000000     5.000000           5.000000        5.00000
# 75%     22.000000    6.000000     6.000000           6.000000        6.00000
# max     28.000000    8.000000     9.000000           9.000000        8.00000
#
#        extraversion
# count    531.000000
# mean       4.894539
# std        1.456342
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        6.000000
# max        8.000000

# %%
df2.isnull().sum()
# Out:
# Gender                       0
# Age                          0
# openness                     0
# neuroticism                  0
# conscientiousness            0
# agreeableness                0
# extraversion                 0
# Personality (class label)    0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 216

# %%
plotCorrelationMatrix(df2, 8)

# %%
plotScatterMatrix(df2, 18, 10)

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# train.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df3 = pd.read_csv('train.csv', delimiter=',', nrows = nRowsRead)
df3.dataframeName = 'train.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 8 columns

# %%
df3.head(5)
# Out:
#    Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0    Male   17         7            4                  7              3
# 1    Male   19         4            5                  4              6
# 2  Female   18         7            6                  4              5
# 3  Female   22         5            6                  7              4
# 4  Female   19         7            4                  6              5
#
#    extraversion Personality (Class label)
# 0             2               extraverted
# 1             6                   serious
# 2             5                dependable
# 3             3               extraverted
# 4             4                    lively

# %%
df3.tail()
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 995  Female   19         1            1                  5              5
# 996  Female   19         7            6                  6              5
# 997  Female   19         5            7                  7              7
# 998    Male   18         6            7                  5              4
# 999  Female   19         7            4                  4              4
#
#      extraversion Personality (Class label)
# 995             6                dependable
# 996             7                dependable
# 997             4               responsible
# 998             1                dependable
# 999             6               responsible

# %%
df3.describe()
# Out:
#                Age     openness  neuroticism  conscientiousness  \
# count  1000.000000  1000.000000  1000.000000        1000.000000
# mean     19.491000     5.037000     4.616000           4.574000
# std       2.402018     1.527732     1.682074           1.748594
# min       5.000000     1.000000     1.000000           1.000000
# 25%      18.000000     4.000000     4.000000           3.000000
# 50%      19.000000     5.000000     5.000000           5.000000
# 75%      20.000000     6.000000     6.000000           6.000000
# max      28.000000     8.000000     8.000000           8.000000
#
#        agreeableness  extraversion
# count    1000.000000   1000.000000
# mean        4.831000      4.280000
# std         1.690946      1.624265
# min         1.000000      1.000000
# 25%         4.000000      3.000000
# 50%         5.000000      4.000000
# 75%         6.000000      5.000000
# max         8.000000      7.000000

# %%
df3.isnull().sum()
# Out:
# Gender                       0
# Age                          0
# openness                     0
# neuroticism                  0
# conscientiousness            0
# agreeableness                0
# extraversion                 0
# Personality (Class label)    0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 406

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
plotCorrelationMatrix(df3, 8)

# %%
plotScatterMatrix(df3, 18, 10)

# %%
df2.head(50)
# Out:
#     Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0   Female   20         7            9                  9              5
# 1     Male   17         5            4                  5              2
# 2   Female   25         5            5                  7              2
# 3   Female   18         6            2                  7              4
# 4   Female   19         2            4                  7              1
# 5   Female   19         6            4                  7              5
# 6   Female   24         1            2                  7              4
# 7     Male   27         4            5                  7              4
# 8     Male   20         6            4                  5              6
# 9     Male   21         5            4                  4              6
# 10    Male   20         6            1                  7              6
# 11    Male   19         4            4                  4              4
# 12  Female   20         4            5                  5              5
# 13  Female   20         4            4                  4              4
# 14  Female   19         7            2                  4              3
# 15  Female   17         6            6                  5              7
# 16    Male   17         5            4                  6              6
# 17    Male   18         5            3                  5              6
# 18    Male   23         4            2                  1              5
# 19  Female   23         5            4                  4              5
# 20  Female   24         5            3                  7              3
# 21  Female   25         5            7                  3              7
# 22  Female   20         4            5                  6              5
# 23    Male   19         6            6                  5              1
# 24  Female   19         6            1                  5              5
# 25    Male   17         6            6                  7              6
# 26    Male   17         4            6                  3              5
# 27    Male   22         6            8                  2              6
# 28    Male   23         3            6                  6              7
# 29  Female   21         4            2                  3              5
# 30    Male   19         4            4                  6              4
# 31    Male   24         6            2                  5              2
# 32    Male   25         5            5                  1              7
# 33  Female   26         6            2                  6              3
# 34    Male   23         7            4                  7              5
# 35  Female   18         4            4                  6              3
# 36    Male   19         2            4                  5              5
# 37    Male   20         2            2                  4              7
# 38  Female   17         3            7                  3              3
# 39  Female   21         5            4                  6              1
# 40    Male   18         5            4                  6              2
# 41  Female   19         2            5                  4              6
# 42  Female   22         3            6                  6              1
# 43  Female   20         8            2                  5              1
# 44  Female   25         4            6                  6              3
# 45    Male   24         5            6                  3              3
# 46  Female   17         5            6                  6              2
# 47  Female   21         5            6                  7              4
# 48  Female   25         2            5                  4              4
# 49    Male   23         5            7                  1              3
#
#     extraversion Personality (class label)
# 0              5                dependable
# 1              4                   serious
# 2              4                   serious
# 3              7                   serious
# 4              3               responsible
# 5              5                   serious
# 6              6               extraverted
# 7              4                   serious
# 8              6                   serious
# 9              4                   serious
# 10             5                   serious
# 11             3               responsible
# 12             2               responsible
# 13             5                   serious
# 14             4                    lively
# 15             6               extraverted
# 16             5                   serious
# 17             7                   serious
# 18             6                   serious
# 19             4               extraverted
# 20             5                   serious
# 21             6                dependable
# 22             5                   serious
# 23             3               extraverted
# 24             6               extraverted
# 25             4                   serious
# 26             4               extraverted
# 27             4                dependable
# 28             3                   serious
# 29             4               responsible
# 30             3                   serious
# 31             2                    lively
# 32             6               extraverted
# 33             3                    lively
# 34             5                   serious
# 35             5                   serious
# 36             6                   serious
# 37             5                   serious
# 38             7               extraverted
# 39             5                   serious
# 40             1               responsible
# 41             3               responsible
# 42             6                   serious
# 43             4               extraverted
# 44             6                dependable
# 45             8                   serious
# 46             3               responsible
# 47             6                dependable
# 48             7                   serious
# 49             6               extraverted

# %%
df2.tail(50)
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 481    Male   21         6            4                  7              5
# 482    Male   18         4            6                  3              6
# 483    Male   17         5            4                  5              8
# 484  Female   17         5            4                  6              7
# 485  Female   21         5            5                  7              6
# 486    Male   20         7            5                  5              4
# 487    Male   18         6            3                  6              6
# 488  Female   19         3            5                  3              5
# 489  Female   23         6            6                  6              4
# 490    Male   18         8            3                  6              7
# 491  Female   18         2            7                  6              6
# 492  Female   20         6            6                  1              5
# 493    Male   24         6            7                  3              1
# 494  Female   20         5            8                  2              5
# 495    Male   18         7            7                  8              4
# 496    Male   18         6            6                  3              6
# 497    Male   23         6            6                  3              6
# 498  Female   18         7            7                  7              5
# 499    Male   21         7            6                  6              6
# 500    Male   21         6            7                  7              4
# 501    Male   22         4            6                  3              5
# 502    Male   18         5            7                  5              4
# 503  Female   19         6            6                  5              4
# 504    Male   19         2            5                  5              3
# 505    Male   23         5            4                  6              4
# 506    Male   19         7            8                  7              4
# 507    Male   19         1            6                  7              8
# 508  Female   20         3            7                  3              2
# 509  Female   18         5            6                  7              5
# 510    Male   21         6            7                  7              6
# 511  Female   20         2            6                  5              5
# 512    Male   17         3            7                  6              3
# 513    Male   22         3            7                  6              6
# 514  Female   19         6            6                  3              5
# 515  Female   17         6            7                  4              4
# 516    Male   20         3            7                  7              5
# 517    Male   22         4            4                  5              2
# 518  Female   19         6            8                  1              3
# 519    Male   19         6            5                  6              7
# 520  Female   21         4            5                  7              7
# 521    Male   18         7            5                  7              5
# 522    Male   26         2            5                  3              6
# 523  Female   26         3            6                  6              6
# 524    Male   24         5            4                  5              7
# 525  Female   18         2            6                  6              7
# 526  Female   20         5            6                  2              2
# 527    Male   18         6            5                  5              5
# 528    Male   19         1            5                  4              7
# 529  Female   22         3            3                  2              6
# 530  Female   17         6            6                  3              6
#
#      extraversion Personality (class label)
# 481             5                   serious
# 482             5                   serious
# 483             1                    lively
# 484             5               extraverted
# 485             4                   serious
# 486             5                   serious
# 487             6                   serious
# 488             5               extraverted
# 489             6               responsible
# 490             6                   serious
# 491             4               extraverted
# 492             5               responsible
# 493             5               extraverted
# 494             7               extraverted
# 495             2                    lively
# 496             6                dependable
# 497             3               extraverted
# 498             6                dependable
# 499             5                   serious
# 500             5                dependable
# 501             4                    lively
# 502             5               extraverted
# 503             4                dependable
# 504             7                   serious
# 505             5                   serious
# 506             3               extraverted
# 507             7                   serious
# 508             5               extraverted
# 509             4               responsible
# 510             5                   serious
# 511             3               extraverted
# 512             7                   serious
# 513             7                   serious
# 514             7                   serious
# 515             5               extraverted
# 516             6                   serious
# 517             3                   serious
# 518             6               extraverted
# 519             5                   serious
# 520             5                   serious
# 521             5                   serious
# 522             6                   serious
# 523             5               extraverted
# 524             8                   serious
# 525             6               extraverted
# 526             3               extraverted
# 527             7                   serious
# 528             6                   serious
# 529             4               responsible
# 530             5               extraverted

# %%
df3.head(50)
# Out:
#     Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0     Male   17         7            4                  7              3
# 1     Male   19         4            5                  4              6
# 2   Female   18         7            6                  4              5
# 3   Female   22         5            6                  7              4
# 4   Female   19         7            4                  6              5
# 5     Male   18         5            7                  7              6
# 6   Female   17         5            6                  5              7
# 7   Female   19         6            6                  7              5
# 8     Male   18         5            7                  5              6
# 9   Female   19         5            5                  7              4
# 10    Male   19         6            7                  5              6
# 11    Male   19         7            6                  7              7
# 12    Male   19         7            6                  6              5
# 13  Female   19         6            7                  5              5
# 14  Female   19         5            5                  4              5
# 15    Male   19         5            6                  4              6
# 16  Female   19         7            7                  2              6
# 17  Female   18         6            7                  4              4
# 18  Female   19         6            6                  6              4
# 19  Female   19         5            6                  3              3
# 20  Female   19         6            4                  6              3
# 21    Male   18         4            5                  4              3
# 22  Female   19         5            4                  5              5
# 23    Male   20         5            3                  3              4
# 24  Female   19         6            7                  5              5
# 25  Female   19         7            5                  6              6
# 26  Female   18         6            4                  5              5
# 27  Female   19         4            6                  4              7
# 28  Female   27         6            5                  6              4
# 29  Female   17         7            4                  7              6
# 30  Female   21         6            6                  3              5
# 31    Male   18         6            5                  5              6
# 32  Female   18         6            6                  5              6
# 33    Male   18         6            3                  5              5
# 34    Male   18         5            7                  3              6
# 35  Female   19         7            6                  6              6
# 36  Female   18         7            6                  6              7
# 37  Female   18         7            7                  5              7
# 38  Female   17         7            5                  7              7
# 39  Female   20         6            5                  4              5
# 40    Male   19         3            5                  3              4
# 41  Female   17         6            7                  6              6
# 42  Female   18         7            5                  6              6
# 43  Female   20         5            7                  5              6
# 44    Male   28         6            5                  7              6
# 45    Male   17         5            6                  5              5
# 46  Female   18         5            5                  4              4
# 47  Female   20         7            6                  6              4
# 48  Female   18         6            4                  3              6
# 49  Female   19         6            4                  5              6
#
#     extraversion Personality (Class label)
# 0              2               extraverted
# 1              6                   serious
# 2              5                dependable
# 3              3               extraverted
# 4              4                    lively
# 5              4                    lively
# 6              4               extraverted
# 7              4               extraverted
# 8              7                dependable
# 9              5                    lively
# 10             3                   serious
# 11             6               extraverted
# 12             6                    lively
# 13             5                dependable
# 14             4               responsible
# 15             3               extraverted
# 16             5                   serious
# 17             2                dependable
# 18             3               responsible
# 19             3               extraverted
# 20             4               responsible
# 21             6               extraverted
# 22             3               responsible
# 23             4                   serious
# 24             4                   serious
# 25             5                dependable
# 26             4               extraverted
# 27             6               extraverted
# 28             5                    lively
# 29             5                    lively
# 30             4               extraverted
# 31             1               extraverted
# 32             3                dependable
# 33             4                    lively
# 34             4                   serious
# 35             5                    lively
# 36             5               responsible
# 37             3               responsible
# 38             2                dependable
# 39             5                   serious
# 40             2                dependable
# 41             6               extraverted
# 42             4                   serious
# 43             3               extraverted
# 44             4                dependable
# 45             3                dependable
# 46             3               responsible
# 47             4                   serious
# 48             2                    lively
# 49             4                    lively

# %%
df3.tail(50)
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 548    Male   18         1            6                  6              7
# 549  Female   20         7            7                  5              7
# 550  Female   21         7            3                  7              7
# 551  Female   18         6            5                  4              5
# 552    Male   23         3            5                  5              4
# 553  Female   25         6            7                  6              6
# 554  Female   18         7            5                  6              6
# 555  Female   20         5            5                  5              6
# 556    Male   23         6            5                  7              6
# 557    Male   21         5            6                  5              5
# 558  Female   22         5            5                  4              4
# 559  Female   20         7            5                  5              5
# 560    Male   18         6            4                  3              6
# 561    Male   17         6            4                  7              6
# 562  Female   19         3            4                  5              5
# 563  Female   18         4            4                  4              6
# 565    Male   23         7            7                  4              4
# 566  Female   19         7            6                  7              6
# 567    Male   18         7            5                  6              4
# 568  Female   17         4            5                  4              8
# 569    Male   22         6            6                  5              4
# 570  Female   19         7            8                  5              4
# 571    Male   19         5            4                  3              6
# 572    Male   19         3            7                  2              6
# 573    Male   23         7            6                  5              5
# 574  Female   19         7            7                  4              5
# 575    Male   19         6            6                  4              8
# 576  Female   18         7            5                  5              4
# 577  Female   24         6            6                  5              5
# 578  Female   17         7            6                  5              4
# 579  Female   19         5            6                  6              7
# 580    Male   19         6            5                  5              6
# 581    Male   22         5            5                  5              7
# 582    Male   18         7            8                  4              4
# 583    Male   18         7            6                  8              5
# 584  Female   17         5            5                  5              5
# 585    Male   24         5            5                  4              4
# 586  Female   18         6            6                  5              6
# 587  Female   18         7            4                  7              7
# 588  Female   17         4            6                  4              4
# 589    Male   24         7            4                  5              5
# 590  Female   19         5            5                  5              5
# 591  Female   18         5            1                  6              6
# 592    Male   18         3            6                  3              3
# 593    Male   22         7            5                  7              5
# 594    Male   21         8            8                  5              5
# 595  Female   21         6            5                  4              7
# 596  Female   18         6            4                  4              6
# 597  Female   22         7            5                  7              6
# 598  Female   19         6            3                  7              4
#
#      extraversion Personality (Class label)
# 548             5               responsible
# 549             3                dependable
# 550             3                dependable
# 551             5                   serious
# 552             2               responsible
# 553             6               extraverted
# 554             4                    lively
# 555             2               extraverted
# 556             4                dependable
# 557             3                   serious
# 558             3               responsible
# 559             5                   serious
# 560             2                    lively
# 561             4                    lively
# 562             1               responsible
# 563             1               extraverted
# 565             5               extraverted
# 566             6                    lively
# 567             3                   serious
# 568             4               extraverted
# 569             4                dependable
# 570             7                    lively
# 571             3                    lively
# 572             5                   serious
# 573             5               extraverted
# 574             2               responsible
# 575             6                dependable
# 576             4                    lively
# 577             4                   serious
# 578             4               responsible
# 579             4                dependable
# 580             4                    lively
# 581             3                dependable
# 582             3               extraverted
# 583             7               extraverted
# 584             6                    lively
# 585             4                dependable
# 586             4               responsible
# 587             4                   serious
# 588             7               extraverted
# 589             5                dependable
# 590             6                    lively
# 591             2                    lively
# 592             7               responsible
# 593             2                    lively
# 594             3                   serious
# 595             2               responsible
# 596             5                    lively
# 597             1                   serious
# 598             4                dependable

# %%
df = pd.concat([df2, df3])
df.head()
# Out:
#    Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0  Female   20         7            9                  9              5
# 1    Male   17         5            4                  5              2
# 2  Female   25         5            5                  7              2
# 3  Female   18         6            2                  7              4
# 4  Female   19         2            4                  7              1
#
#    extraversion Personality (class label) Personality (Class label)
# 0             5                dependable                       NaN
# 1             4                   serious                       NaN
# 2             4                   serious                       NaN
# 3             7                   serious                       NaN
# 4             3               responsible                       NaN

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0    Female   20         7            9                  9              5
# 1      Male   17         5            4                  5              2
# 2    Female   25         5            5                  7              2
# 3    Female   18         6            2                  7              4
# 4    Female   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 594    Male   21         8            8                  5              5
# 595  Female   21         6            5                  4              7
# 596  Female   18         6            4                  4              6
# 597  Female   22         7            5                  7              6
# 598  Female   19         6            3                  7              4
#
#      extraversion Personality (class label) Personality (Class label)
# 0               5                dependable                       NaN
# 1               4                   serious                       NaN
# 2               4                   serious                       NaN
# 3               7                   serious                       NaN
# 4               3               responsible                       NaN
# ..            ...                       ...                       ...
# 594             3                       NaN                   serious
# 595             2                       NaN               responsible
# 596             5                       NaN                    lively
# 597             1                       NaN                   serious
# 598             4                       NaN                dependable
#
# [1125 rows x 9 columns]

# %%
df=df.drop("Personality (Class label)",axis=1)

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0    Female   20         7            9                  9              5
# 1      Male   17         5            4                  5              2
# 2    Female   25         5            5                  7              2
# 3    Female   18         6            2                  7              4
# 4    Female   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 594    Male   21         8            8                  5              5
# 595  Female   21         6            5                  4              7
# 596  Female   18         6            4                  4              6
# 597  Female   22         7            5                  7              6
# 598  Female   19         6            3                  7              4
#
#      extraversion Personality (class label)
# 0               5                dependable
# 1               4                   serious
# 2               4                   serious
# 3               7                   serious
# 4               3               responsible
# ..            ...                       ...
# 594             3                       NaN
# 595             2                       NaN
# 596             5                       NaN
# 597             1                       NaN
# 598             4                       NaN
#
# [1125 rows x 8 columns]

# %%
df.head(50)
# Out:
#     Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0   Female   20         7            9                  9              5
# 1     Male   17         5            4                  5              2
# 2   Female   25         5            5                  7              2
# 3   Female   18         6            2                  7              4
# 4   Female   19         2            4                  7              1
# 5   Female   19         6            4                  7              5
# 6   Female   24         1            2                  7              4
# 7     Male   27         4            5                  7              4
# 8     Male   20         6            4                  5              6
# 9     Male   21         5            4                  4              6
# 10    Male   20         6            1                  7              6
# 11    Male   19         4            4                  4              4
# 12  Female   20         4            5                  5              5
# 13  Female   20         4            4                  4              4
# 14  Female   19         7            2                  4              3
# 15  Female   17         6            6                  5              7
# 16    Male   17         5            4                  6              6
# 17    Male   18         5            3                  5              6
# 18    Male   23         4            2                  1              5
# 19  Female   23         5            4                  4              5
# 20  Female   24         5            3                  7              3
# 21  Female   25         5            7                  3              7
# 22  Female   20         4            5                  6              5
# 23    Male   19         6            6                  5              1
# 24  Female   19         6            1                  5              5
# 25    Male   17         6            6                  7              6
# 26    Male   17         4            6                  3              5
# 27    Male   22         6            8                  2              6
# 28    Male   23         3            6                  6              7
# 29  Female   21         4            2                  3              5
# 30    Male   19         4            4                  6              4
# 31    Male   24         6            2                  5              2
# 32    Male   25         5            5                  1              7
# 33  Female   26         6            2                  6              3
# 34    Male   23         7            4                  7              5
# 35  Female   18         4            4                  6              3
# 36    Male   19         2            4                  5              5
# 37    Male   20         2            2                  4              7
# 38  Female   17         3            7                  3              3
# 39  Female   21         5            4                  6              1
# 40    Male   18         5            4                  6              2
# 41  Female   19         2            5                  4              6
# 42  Female   22         3            6                  6              1
# 43  Female   20         8            2                  5              1
# 44  Female   25         4            6                  6              3
# 45    Male   24         5            6                  3              3
# 46  Female   17         5            6                  6              2
# 47  Female   21         5            6                  7              4
# 48  Female   25         2            5                  4              4
# 49    Male   23         5            7                  1              3
#
#     extraversion Personality (class label)
# 0              5                dependable
# 1              4                   serious
# 2              4                   serious
# 3              7                   serious
# 4              3               responsible
# 5              5                   serious
# 6              6               extraverted
# 7              4                   serious
# 8              6                   serious
# 9              4                   serious
# 10             5                   serious
# 11             3               responsible
# 12             2               responsible
# 13             5                   serious
# 14             4                    lively
# 15             6               extraverted
# 16             5                   serious
# 17             7                   serious
# 18             6                   serious
# 19             4               extraverted
# 20             5                   serious
# 21             6                dependable
# 22             5                   serious
# 23             3               extraverted
# 24             6               extraverted
# 25             4                   serious
# 26             4               extraverted
# 27             4                dependable
# 28             3                   serious
# 29             4               responsible
# 30             3                   serious
# 31             2                    lively
# 32             6               extraverted
# 33             3                    lively
# 34             5                   serious
# 35             5                   serious
# 36             6                   serious
# 37             5                   serious
# 38             7               extraverted
# 39             5                   serious
# 40             1               responsible
# 41             3               responsible
# 42             6                   serious
# 43             4               extraverted
# 44             6                dependable
# 45             8                   serious
# 46             3               responsible
# 47             6                dependable
# 48             7                   serious
# 49             6               extraverted

# %%
df.tail(50)
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 548    Male   18         1            6                  6              7
# 549  Female   20         7            7                  5              7
# 550  Female   21         7            3                  7              7
# 551  Female   18         6            5                  4              5
# 552    Male   23         3            5                  5              4
# 553  Female   25         6            7                  6              6
# 554  Female   18         7            5                  6              6
# 555  Female   20         5            5                  5              6
# 556    Male   23         6            5                  7              6
# 557    Male   21         5            6                  5              5
# 558  Female   22         5            5                  4              4
# 559  Female   20         7            5                  5              5
# 560    Male   18         6            4                  3              6
# 561    Male   17         6            4                  7              6
# 562  Female   19         3            4                  5              5
# 563  Female   18         4            4                  4              6
# 565    Male   23         7            7                  4              4
# 566  Female   19         7            6                  7              6
# 567    Male   18         7            5                  6              4
# 568  Female   17         4            5                  4              8
# 569    Male   22         6            6                  5              4
# 570  Female   19         7            8                  5              4
# 571    Male   19         5            4                  3              6
# 572    Male   19         3            7                  2              6
# 573    Male   23         7            6                  5              5
# 574  Female   19         7            7                  4              5
# 575    Male   19         6            6                  4              8
# 576  Female   18         7            5                  5              4
# 577  Female   24         6            6                  5              5
# 578  Female   17         7            6                  5              4
# 579  Female   19         5            6                  6              7
# 580    Male   19         6            5                  5              6
# 581    Male   22         5            5                  5              7
# 582    Male   18         7            8                  4              4
# 583    Male   18         7            6                  8              5
# 584  Female   17         5            5                  5              5
# 585    Male   24         5            5                  4              4
# 586  Female   18         6            6                  5              6
# 587  Female   18         7            4                  7              7
# 588  Female   17         4            6                  4              4
# 589    Male   24         7            4                  5              5
# 590  Female   19         5            5                  5              5
# 591  Female   18         5            1                  6              6
# 592    Male   18         3            6                  3              3
# 593    Male   22         7            5                  7              5
# 594    Male   21         8            8                  5              5
# 595  Female   21         6            5                  4              7
# 596  Female   18         6            4                  4              6
# 597  Female   22         7            5                  7              6
# 598  Female   19         6            3                  7              4
#
#      extraversion Personality (class label)
# 548             5                       NaN
# 549             3                       NaN
# 550             3                       NaN
# 551             5                       NaN
# 552             2                       NaN
# 553             6                       NaN
# 554             4                       NaN
# 555             2                       NaN
# 556             4                       NaN
# 557             3                       NaN
# 558             3                       NaN
# 559             5                       NaN
# 560             2                       NaN
# 561             4                       NaN
# 562             1                       NaN
# 563             1                       NaN
# 565             5                       NaN
# 566             6                       NaN
# 567             3                       NaN
# 568             4                       NaN
# 569             4                       NaN
# 570             7                       NaN
# 571             3                       NaN
# 572             5                       NaN
# 573             5                       NaN
# 574             2                       NaN
# 575             6                       NaN
# 576             4                       NaN
# 577             4                       NaN
# 578             4                       NaN
# 579             4                       NaN
# 580             4                       NaN
# 581             3                       NaN
# 582             3                       NaN
# 583             7                       NaN
# 584             6                       NaN
# 585             4                       NaN
# 586             4                       NaN
# 587             4                       NaN
# 588             7                       NaN
# 589             5                       NaN
# 590             6                       NaN
# 591             2                       NaN
# 592             7                       NaN
# 593             2                       NaN
# 594             3                       NaN
# 595             2                       NaN
# 596             5                       NaN
# 597             1                       NaN
# 598             4                       NaN

# %%
df.isnull().sum()
# Out:
# Gender                         0
# Age                            0
# openness                       0
# neuroticism                    0
# conscientiousness              0
# agreeableness                  0
# extraversion                   0
# Personality (class label)    594
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                       0
# Age                          0
# openness                     0
# neuroticism                  0
# conscientiousness            0
# agreeableness                0
# extraversion                 0
# Personality (class label)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 216

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0    Female   20         7            9                  9              5
# 1      Male   17         5            4                  5              2
# 2    Female   25         5            5                  7              2
# 3    Female   18         6            2                  7              4
# 4    Female   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 526  Female   20         5            6                  2              2
# 527    Male   18         6            5                  5              5
# 528    Male   19         1            5                  4              7
# 529  Female   22         3            3                  2              6
# 530  Female   17         6            6                  3              6
#
#      extraversion Personality (class label)
# 0               5                dependable
# 1               4                   serious
# 2               4                   serious
# 3               7                   serious
# 4               3               responsible
# ..            ...                       ...
# 526             3               extraverted
# 527             7                   serious
# 528             6                   serious
# 529             4               responsible
# 530             5               extraverted
#
# [531 rows x 8 columns]

# %%
df['Gender'] = df['Gender'].map({'Male': 0,
                                 'Female': 1})

df['Personality (class label)'] = df['Personality (class label)'].map({'dependable': 0,
                                           'extraverted': 1,
                                           'lively': 2,
                                           'responsible': 3,
                                           'serious': 4})

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0         1   20         7            9                  9              5
# 1         0   17         5            4                  5              2
# 2         1   25         5            5                  7              2
# 3         1   18         6            2                  7              4
# 4         1   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 526       1   20         5            6                  2              2
# 527       0   18         6            5                  5              5
# 528       0   19         1            5                  4              7
# 529       1   22         3            3                  2              6
# 530       1   17         6            6                  3              6
#
#      extraversion  Personality (class label)
# 0               5                          0
# 1               4                          4
# 2               4                          4
# 3               7                          4
# 4               3                          3
# ..            ...                        ...
# 526             3                          1
# 527             7                          4
# 528             6                          4
# 529             4                          3
# 530             5                          1
#
# [531 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Gender                       0
# Age                          0
# openness                     0
# neuroticism                  0
# conscientiousness            0
# agreeableness                0
# extraversion                 0
# Personality (class label)    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0         1   20         7            9                  9              5
# 1         0   17         5            4                  5              2
# 2         1   25         5            5                  7              2
# 3         1   18         6            2                  7              4
# 4         1   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 526       1   20         5            6                  2              2
# 527       0   18         6            5                  5              5
# 528       0   19         1            5                  4              7
# 529       1   22         3            3                  2              6
# 530       1   17         6            6                  3              6
#
#      extraversion  Personality (class label)
# 0               5                          0
# 1               4                          4
# 2               4                          4
# 3               7                          4
# 4               3                          3
# ..            ...                        ...
# 526             3                          1
# 527             7                          4
# 528             6                          4
# 529             4                          3
# 530             5                          1
#
# [531 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Gender                       0
# Age                          0
# openness                     0
# neuroticism                  0
# conscientiousness            0
# agreeableness                0
# extraversion                 0
# Personality (class label)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 216

# %%
df
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0         1   20         7            9                  9              5
# 1         0   17         5            4                  5              2
# 2         1   25         5            5                  7              2
# 3         1   18         6            2                  7              4
# 4         1   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 526       1   20         5            6                  2              2
# 527       0   18         6            5                  5              5
# 528       0   19         1            5                  4              7
# 529       1   22         3            3                  2              6
# 530       1   17         6            6                  3              6
#
#      extraversion  Personality (class label)
# 0               5                          0
# 1               4                          4
# 2               4                          4
# 3               7                          4
# 4               3                          3
# ..            ...                        ...
# 526             3                          1
# 527             7                          4
# 528             6                          4
# 529             4                          3
# 530             5                          1
#
# [531 rows x 8 columns]

# %%
df.corr()
# Out:
#                              Gender       Age  openness  neuroticism  \
# Gender                     1.000000 -0.032009 -0.020759     0.067200
# Age                       -0.032009  1.000000 -0.100549    -0.003814
# openness                  -0.020759 -0.100549  1.000000    -0.019562
# neuroticism                0.067200 -0.003814 -0.019562     1.000000
# conscientiousness         -0.107101 -0.055935  0.032262     0.061057
# agreeableness             -0.064120 -0.042356 -0.078280    -0.190076
# extraversion              -0.018317  0.024346 -0.092876     0.025286
# Personality (class label) -0.365932  0.032491 -0.165274    -0.357211
#
#                            conscientiousness  agreeableness  extraversion  \
# Gender                             -0.107101      -0.064120     -0.018317
# Age                                -0.055935      -0.042356      0.024346
# openness                            0.032262      -0.078280     -0.092876
# neuroticism                         0.061057      -0.190076      0.025286
# conscientiousness                   1.000000      -0.014121     -0.114849
# agreeableness                      -0.014121       1.000000      0.079296
# extraversion                       -0.114849       0.079296      1.000000
# Personality (class label)           0.154697       0.075463      0.237400
#
#                            Personality (class label)
# Gender                                     -0.365932
# Age                                         0.032491
# openness                                   -0.165274
# neuroticism                                -0.357211
# conscientiousness                           0.154697
# agreeableness                               0.075463
# extraversion                                0.237400
# Personality (class label)                   1.000000

# %%
df.describe()
# Out:
#            Gender         Age    openness  neuroticism  conscientiousness  \
# count  531.000000  531.000000  531.000000   531.000000         531.000000
# mean     0.463277   20.122411    4.860640     4.917137           4.838041
# std      0.499120    2.493404    1.587503     1.709217           1.805689
# min      0.000000    5.000000    1.000000     1.000000           1.000000
# 25%      0.000000   18.000000    4.000000     4.000000           3.000000
# 50%      0.000000   19.000000    5.000000     5.000000           5.000000
# 75%      1.000000   22.000000    6.000000     6.000000           6.000000
# max      1.000000   28.000000    8.000000     9.000000           9.000000
#
#        agreeableness  extraversion  Personality (class label)
# count      531.00000    531.000000                 531.000000
# mean         4.94162      4.894539                   2.619586
# std          1.62944      1.456342                   1.460910
# min          1.00000      1.000000                   0.000000
# 25%          4.00000      4.000000                   1.000000
# 50%          5.00000      5.000000                   3.000000
# 75%          6.00000      6.000000                   4.000000
# max          8.00000      8.000000                   4.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.skew()
# Out:
# Gender                       0.147708
# Age                          0.319610
# openness                    -0.548252
# neuroticism                 -0.453174
# conscientiousness           -0.470988
# agreeableness               -0.438839
# extraversion                -0.411878
# Personality (class label)   -0.388657
# dtype: float64

# %%
X=df.drop('Personality (class label)',axis=1)
y=df['Personality (class label)']

# %%
X
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0         1   20         7            9                  9              5
# 1         0   17         5            4                  5              2
# 2         1   25         5            5                  7              2
# 3         1   18         6            2                  7              4
# 4         1   19         2            4                  7              1
# ..      ...  ...       ...          ...                ...            ...
# 526       1   20         5            6                  2              2
# 527       0   18         6            5                  5              5
# 528       0   19         1            5                  4              7
# 529       1   22         3            3                  2              6
# 530       1   17         6            6                  3              6
#
#      extraversion
# 0               5
# 1               4
# 2               4
# 3               7
# 4               3
# ..            ...
# 526             3
# 527             7
# 528             6
# 529             4
# 530             5
#
# [531 rows x 7 columns]

# %%
y
# Out:
# 0      0
# 1      4
# 2      4
# 3      4
# 4      3
#       ..
# 526    1
# 527    4
# 528    4
# 529    3
# 530    1
# Name: Personality (class label), Length: 531, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,r2_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=52)

# %%
X_train
# Out:
#      Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 53        0   24         4            5                  5              6
# 37        0   20         2            2                  4              7
# 375       0   19         6            5                  6              7
# 384       0   19         1            5                  4              7
# 388       0   21         4            4                  1              6
# ..      ...  ...       ...          ...                ...            ...
# 234       1   17         6            7                  4              4
# 503       1   19         6            6                  5              4
# 86        1   23         2            2                  6              4
# 151       0   20         6            1                  6              4
# 525       1   18         2            6                  6              7
#
#      extraversion
# 53              2
# 37              5
# 375             5
# 384             6
# 388             4
# ..            ...
# 234             5
# 503             4
# 86              6
# 151             4
# 525             6
#
# [424 rows x 7 columns]

# %%
y_train
# Out:
# 53     2
# 37     4
# 375    4
# 384    4
# 388    4
#       ..
# 234    1
# 503    0
# 86     4
# 151    2
# 525    1
# Name: Personality (class label), Length: 424, dtype: int64

# %%
rfc1=RandomForestClassifier(n_estimators=1000)
rfc1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
predictions_rfc1=rfc1.predict(X_test)

# %%
rf_recovery = accuracy_score(y_test,predictions_rfc1)
rf_recovery
# Out:
# 0.8317757009345794

# %%
print(confusion_matrix(y_test,predictions_rfc1))
print('\n')
print(classification_report(y_test,predictions_rfc1))
# Out:
# [[ 5  1  0  0  2]
#  [ 0 25  1  0  3]
#  [ 0  0  8  0  1]
#  [ 0  2  1  8  6]
#  [ 0  1  0  0 43]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.77         8
#            1       0.86      0.86      0.86        29
#            2       0.80      0.89      0.84         9
#            3       1.00      0.47      0.64        17
#            4       0.78      0.98      0.87        44
#
#     accuracy                           0.83       107
#    macro avg       0.89      0.76      0.80       107
# weighted avg       0.86      0.83      0.82       107

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report , confusion_matrix

# %%
logistic_model = LogisticRegression(random_state = 0)
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_predict =logistic_model.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_predict)
sns.heatmap(cm ,annot=True)
# Out:
# <Axes: >

# %%
print("accuracy :" , logistic_model.score(X_test,y_test))
# Out:
# accuracy : 0.6542056074766355

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.69      0.76      0.72        29
#            2       0.80      0.44      0.57         9
#            3       0.60      0.18      0.27        17
#            4       0.63      0.93      0.75        44
#
#     accuracy                           0.65       107
#    macro avg       0.54      0.46      0.46       107
# weighted avg       0.61      0.65      0.60       107

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)
print("accuracy :" , knn_model.score(X_test,y_test))
# Out:
# accuracy : 0.7102803738317757

# %%
cmt = confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cmt ,annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      0.12      0.15         8
#            1       0.76      0.86      0.81        29
#            2       0.83      0.56      0.67         9
#            3       0.55      0.35      0.43        17
#            4       0.75      0.89      0.81        44
#
#     accuracy                           0.71       107
#    macro avg       0.62      0.56      0.57       107
# weighted avg       0.69      0.71      0.69       107

# %%
from sklearn.svm import SVC

# %%
su=SVC()

# %%
su.fit(X_train, y_train)
y_pred = su.predict(X_test)
print("accuracy :" , knn_model.score(X_test,y_test))
# Out:
# accuracy : 0.7102803738317757

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5981308411214953
